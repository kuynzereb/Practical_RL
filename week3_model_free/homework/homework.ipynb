# %% [markdown]
# ### Practical_RL week3 homework
#
# In this notebook we'll get more perspective on how value-based methods work.
#
# We assume that you've already done either seminar_main or seminar_alternative.
#
# To begin with, __please edit qlearning.py__ - just copy your implementation from the first part of this assignment.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import clear_output

#XVFB will be launched if you run on a server
# import os
# if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
#     !bash ../../xvfb start
#     %env DISPLAY=:1

# %%
def play_and_show(env, agent, t_max=500):
    """This function should 
    - run a full game, actions given by agent.getAction(s)
    - train agent using agent.update(...) whenever possible
    - return total reward"""
    s = env.reset()
    
    for t in range(t_max):
        a = agent.getAction(s)
        next_s, r, done, _ = env.step(a)
        agent.update(s, a, next_s, r)
        
        s = next_s
        
        clear_output(True)
        plt.imshow(env.render('rgb_array'))
        plt.show()
        if done:
            break

# %% [markdown]
# ## 1. Q-learning in the wild (3 pts)
#
# Here we use the qlearning agent on taxi env from openai gym.
# You will need to insert a few agent functions here.

# %%
import gym
env = gym.make("Taxi-v2")

n_actions = env.action_space.n

# %%
from qlearning import QLearningAgent

agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))

# %%
def play_and_train(env, agent, t_max=10**4):
    """This function should 
    - run a full game, actions given by agent.getAction(s)
    - train agent using agent.update(...) whenever possible
    - return total reward"""
    total_reward = 0.0
    s = env.reset()
    
    for t in range(t_max):
        a = agent.getAction(s)
        next_s, r, done, _ = env.step(a)
        agent.update(s, a, next_s, r)
        
        s = next_s
        total_reward += r
        
        if done:
            break
        
    return total_reward

# %%
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))    
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('Q-learning on Taxi-v2, constant epsilon')
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -7.66

# %% [markdown]
# ### 1.1 reducing epsilon
#
# Try decreasing agent epsilon over time to make him reach positive score.
#
# The straightforward way to do so is to reduce epsilon every N games:
# * either multiply agent.epsilon by a number less than 1 (e.g. 0.99)
# * or substract a small value until it reaches 0
#
# You can, of-course, devise other strategies.
#
# __The goal is to reach positive reward!__

# %%
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon = agent.epsilon * 0.99
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('Q-learning on Taxi-v2, decreasing epsilon')
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 8.76

# %%
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon = agent.epsilon - 1. / 1000
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('Q-learning on Taxi-v2, decreasing epsilon')
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 8.21

# %% [markdown]
# ## 2. Expected value SARSA (1 pt)
#
# Let's try out expected-value SARSA. You will have to implement EV-SARSA as an agent, resembling the one you used in qlearning.py ,
#
# ```<go to expected_value_sarsa.py and implement missing lines in getValue(state)```
#
# __[bonus, 2pt]__ implement EV-SARSA for softmax policy:
#
# $$ \pi(a_i|s) = softmax({Q(s,a_i) \over \tau}) = {e ^ {Q(s,a_i)/ \tau}  \over {\sum_{a_j}  e ^{Q(s,a_j) / \tau }}} $$

# %%
import gym
env = gym.make("Taxi-v2")

n_actions = env.action_space.n

# %%
from expected_value_sarsa import EVSarsaAgent

# %% [markdown]
# ### Train EV-SARSA
#
# Note that it uses __the same update parameters as__ qlearning so you adapt use the ```play_and_train``` code above.
#
# Please try both constant epsilon = 0.25 and decreasing epsilon.

# %%
agent = EVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                     getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    #agent.epsilon = agent.epsilon - 1. / 1000
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('EV-SARSA on Taxi-v2, constant epsilon')
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -6.25

# %%
agent = EVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                     getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon *= 0.99
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('EV-SARSA on Taxi-v2, decreasing epsilon')
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 7.8

# %%
from expected_value_sarsa import SoftMaxEVSarsaAgent

# %%
theta = 1
agent = SoftMaxEVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99, theta=theta,
                            getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    #agent.epsilon = agent.epsilon - 1. / 1000
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('SofMaxEV-SARSA on Taxi-v2, theta={}, constant epsilon'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -8.59

# %%
theta = 10
agent = SoftMaxEVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99, theta=theta,
                            getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    #agent.epsilon = agent.epsilon - 1. / 1000
    if (i + 1) % 100 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('SofMaxEV-SARSA on Taxi-v2, theta={}, constant epsilon'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -23.94

# %%
theta = 0.1
agent = SoftMaxEVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99, theta=theta,
                            getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    #agent.epsilon = agent.epsilon - 1. / 1000
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('SofMaxEV-SARSA on Taxi-v2, theta={}, constant epsilon'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -9.89

# %%
theta = 1
agent = SoftMaxEVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99, theta=theta,
                            getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon *= 0.99
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('SofMaxEV-SARSA on Taxi-v2, theta={}, decreasing epsilon'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 8.69

# %%
theta = 10
agent = SoftMaxEVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99, theta=theta,
                            getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon *= 0.99
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('SofMaxEV-SARSA on Taxi-v2, theta={}, decreasing epsilon'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 7.38

# %%
theta = 0.1
agent = SoftMaxEVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99, theta=theta,
                            getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon *= 0.99
    if (i + 1) % 100 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('SofMaxEV-SARSA on Taxi-v2, theta={}, decreasing epsilon'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 8.22

# %% [markdown]
# Ожидаемо, при больших значениях theta обучение происходит медленнее, потому что поначалу агент выбирает действия достаточно равномерно. Чем меньше значение theta, тем больше алгоритм похож на Q-обучение (потому что в этом случае вероятности становятся вырожднными).

# %% [markdown]
# ## 3. Continuous state space (2 pt)
#
# Use agent to train on CartPole-v0
#
# This environment has a continuous number of states, so you will have to group them into bins somehow.
#
# The simplest way is to use `round(x,n_digits)` (or numpy round) to round real number to a given amount of digits.
#
# The tricky part is to get the n_digits right for each state to train effectively.
#
# Note that you don't need to convert state to integers, but to __tuples__ of any kind of values.

# %%
import gym
env = gym.make("CartPole-v0")
n_actions = env.action_space.n

print("first state:%s"%(env.reset()))
plt.imshow(env.render('rgb_array'))
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# first state:[ 0.02870344 -0.00414894 -0.02739923 -0.02112344]

# %% [markdown]
# ### Play a few games
#
# We need to estimate observation distributions. To do so, we'll play a few games and record all states.

# %%
all_states = []
for _ in range(1000):
    all_states.append(env.reset())
    done = False
    while not done:
        s,r,done,_ = env.step(env.action_space.sample())
        all_states.append(s)
        if done:break
            
all_states = np.array(all_states)

for obs_i in range(env.observation_space.shape[0]):
    
    plt.hist(all_states[:,obs_i],bins=20)
    plt.show()

# %%
from qlearning import QLearningAgent
from expected_value_sarsa import EVSarsaAgent
from expected_value_sarsa import SoftMaxEVSarsaAgent

# %%
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env,agent))    
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        plt.plot(rewards)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-5f2e51439c08> in <module>()
#       3 rewards = []
#       4 for i in range(1000):
# ----> 5     rewards.append(play_and_train(env,agent))
#       6     if (i + 1) % 100 == 0:
#       7         clear_output(True)
#
# <ipython-input-54-8a69810cf16f> in play_and_train(env, agent, t_max)
#      10         a = agent.getAction(s)
#      11         next_s, r, done, _ = env.step(a)
# ---> 12         agent.update(s, a, next_s, r)
#      13
#      14         s = next_s
#
# /mnt/c/ubuntu/rl/week3_model_free/homework/qlearning.py in update(self, state, action, nextState, reward)
#     143         lr = self.alpha
#     144
# --> 145         reference_qvalue = reward + gamma * self.getValue(nextState)
#     146         updated_qvalue = (1 - lr) * self.getQValue(state, action) + \
# ...

# %% [markdown]
# ## Binarize environment

# %%
from gym.core import ObservationWrapper
class Binarizer(ObservationWrapper):
    
    def observation(self, s):    
        
        #state = <round state to some amount digits.>
        #hint: you can do that with round(x,n_digits)
        #you will need to pick a different n_digits for each dimension
        
        s0 = 0
        s1 = round(s[1] / 4, 1)
        s2 = (-0.251 < s[2] < 0.251) * round(s[2] * 2, 1)
        s3 = round(s[3] / 4, 1)

        return (s0, s1, s2, s3)

# %%
env = Binarizer(gym.make("CartPole-v0"))
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
all_states = []
for _ in range(1000):
    all_states.append(env.reset())
    done = False
    while not done:
        s,r,done,_ = env.step(env.action_space.sample())
        all_states.append(s)
        if done:break
            
all_states = np.array(all_states)

for obs_i in range(env.observation_space.shape[0]):
    
    plt.hist(all_states[:,obs_i],bins=20)
    plt.show()

# %% [markdown]
# ## Learn

# %%
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon *= 0.993
    if (i + 1) % 100 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning on CartPol-v0')
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 200.0

# %%
play_and_show(env, agent)

# %% [markdown]
# ## 3.2 EV-sarsa on CartPole
#
# Now train the `EVSarsaAgent` on CartPole-v0 env with binarizer you used above for Q-learning.

# %%
agent = EVSarsaAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                     getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(1000):
    rewards.append(play_and_train(env, agent))
    agent.epsilon = agent.epsilon * 0.993
    if (i + 1) % 100 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('EV-SARSA on CartPole-v0'.format(theta))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 199.48

# %%
play_and_show(env, agent)

# %% [markdown]
# ## 4. Experience replay (4 pts)
#
# There's a powerful technique that you can use to improve sample efficiency for off-policy algorithms: [spoiler] Experience replay :)
#
# The catch is that you can train Q-learning and EV-SARSA on `<s,a,r,s'>` tuples even if they aren't sampled under current agent's policy. So here's what we're gonna do:
#
# #### Training with experience replay
# 1. Play game, sample `<s,a,r,s'>`.
# 2. Update q-values based on `<s,a,r,s'>`.
# 3. Store `<s,a,r,s'>` transition in a buffer.
#  3. If buffer is full, delete earliest data.
# 4. Sample K such transitions from that buffer and update q-values based on them.
#
#
# To enable such training, first we must implement a memory structure that would act like such a buffer.

# %%
import random
class ReplayBuffer(object):
    def __init__(self, size):
        """Create Replay buffer.
        Parameters
        ----------
        size: int
            Max number of transitions to store in the buffer. When the buffer
            overflows the old memories are dropped.
        """
        self._storage = []
        self._maxsize = size

    def __len__(self):
        return len(self._storage)

    def add(self, obs_t, action, reward, obs_tp1, done):
        '''
        Make sure, _storage will not exceed _maxsize. 
        Make sure, FIFO rule is being followed: the oldest examples has to be removed earlier
        '''
        data = (obs_t, action, reward, obs_tp1, done)
        self._storage.append(data)
        if len(self._storage) > self._maxsize:
            self._storage.pop(0)
        
    def sample(self, batch_size):
        """Sample a batch of experiences.
        Parameters
        ----------
        batch_size: int
            How many transitions to sample.
        Returns
        -------
        obs_batch: np.array
            batch of observations
        act_batch: np.array
            batch of actions executed given obs_batch
        rew_batch: np.array
            rewards received as results of executing act_batch
        next_obs_batch: np.array
            next set of observations seen after executing act_batch
        done_mask: np.array
            done_mask[i] = 1 if executing act_batch[i] resulted in
            the end of an episode and 0 otherwise.
        """
        size = self.__len__()
        idxes = np.random.choice(np.arange(size), size=batch_size)
        
        return tuple([np.array(x) for x in zip(*np.array(self._storage, dtype='object')[idxes])])

# %% [markdown]
# Some tests to make sure your buffer works right

# %%
replay = ReplayBuffer(2)
obj1 = tuple(range(5))
obj2 = tuple(range(5, 10))
replay.add(*obj1)
assert replay.sample(1)==obj1, "If there's just one object in buffer, it must be retrieved by buf.sample(1)"
replay.add(*obj2)
assert len(replay._storage)==2, "Please make sure __len__ methods works as intended."
replay.add(*obj2)
assert len(replay._storage)==2, "When buffer is at max capacity, replace objects instead of adding new ones."
assert tuple(np.unique(a) for a in replay.sample(100))==obj2
replay.add(*obj1)
assert max(len(np.unique(a)) for a in replay.sample(100))==2
replay.add(*obj1)
assert tuple(np.unique(a) for a in replay.sample(100))==obj1
print("Success!")
# Out:
# Success!

# %% [markdown]
# Now let's use this buffer to improve training:

# %%
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
replay = ReplayBuffer(10000)

# %%
def play_and_train_with_er(env, agent, replay, t_max=10**4, batch_size=100):
    """This function should 
    - run a full game, actions given by agent.getAction(s)
    - train agent using agent.update(...) whenever possible
    - return total reward"""
    total_reward = 0.0
    s = env.reset()

    for t in range(t_max):
        a = agent.getAction(s)
        next_s, r, done, _ = env.step(a)
        replay.add(s, a, r, next_s, done)
    
        agent.update(s, a, next_s, r)
        
        s = next_s
        total_reward +=r
        if done:
            break
    
    if batch_size > 0:
        s_b, a_b, r_b, ns_b, _ = replay.sample(batch_size)
        if isinstance(s_b[0], np.ndarray):
            s_b = [tuple(x) for x in s_b]
            ns_b = [tuple(x) for x in ns_b]
            
        for x in zip(s_b, a_b, ns_b, r_b):
            agent.update(*x)
    
    return total_reward

# %% [markdown]
# Train with experience replay

# %%
import gym
env = gym.make("Taxi-v2")

n_actions = env.action_space.n

# %%
bsize = 0
replay = ReplayBuffer(10000)
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(200):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.99
    if (i + 1) % 50 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning with ER on Taxi-v2, batch_size={}'.format(bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -63.32

# %%
bsize = 50
replay = ReplayBuffer(10000)
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(200):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.99
    if (i + 1) % 50 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning with ER on Taxi-v2, batch_size={}'.format(bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward -15.72

# %%
bsize = 500
replay = ReplayBuffer(10000)
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(200):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.99
    if (i + 1) % 50 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning with ER on Taxi-v2, batch_size={}'.format(bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 4.14

# %%
bsize = 1000
replay = ReplayBuffer(10000)
agent = QLearningAgent(alpha=0.5, epsilon=0.25, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(200):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.99
    if (i + 1) % 50 ==0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning with ER on Taxi-v2, batch_size={}'.format(bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 5.37

# %%
from gym.core import ObservationWrapper
class Binarizer(ObservationWrapper):
    
    def observation(self, s):    
        
        #state = <round state to some amount digits.>
        #hint: you can do that with round(x,n_digits)
        #you will need to pick a different n_digits for each dimension
        
        s0 = 0
        s1 = round(s[1] / 4, 1)
        s2 = (-0.251 < s[2] < 0.251) * round(s[2] * 2, 1)
        s3 = round(s[3] / 4, 1)

        return (s0, s1, s2, s3)

# %%
env = Binarizer(gym.make("CartPole-v0"))
n_actions = env.action_space.n
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
buffer_size = 10000
bsize = 500
replay = ReplayBuffer(buffer_size)
agent = EVSarsaAgent(alpha=0.5, epsilon=0.7, discount=0.99,
                     getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(300):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.96
    if (i + 1) % 50 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('EV-SARSA with ER on CartPole-v0, buffer_size={}, batch_size={}'.format(buffer_size, bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 100.34

# %%
buffer_size = 10000
bsize = 500
replay = ReplayBuffer(buffer_size)
agent = QLearningAgent(alpha=0.5, epsilon=0.7, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(300):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.96
    if (i + 1) % 50 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning with ER on CartPole-v0, buffer_size={}, batch_size={}'.format(buffer_size, bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 186.55

# %%
buffer_size = 1000
bsize = 500
replay = ReplayBuffer(buffer_size)
agent = EVSarsaAgent(alpha=0.5, epsilon=0.7, discount=0.99,
                     getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(300):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.96
    if (i + 1) % 50 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('EV-SARSA with ER on CartPole-v0, buffer_size={}, batch_size={}'.format(buffer_size, bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 193.6

# %%
buffer_size = 1000
bsize = 500
replay = ReplayBuffer(buffer_size)
agent = QLearningAgent(alpha=0.5, epsilon=0.7, discount=0.99,
                       getLegalActions = lambda s: range(n_actions))
rewards = []
for i in range(300):
    rewards.append(play_and_train_with_er(env, agent, replay, batch_size=bsize))
    agent.epsilon = agent.epsilon * 0.95
    if (i + 1) % 50 == 0:
        clear_output(True)
        print("mean reward", np.mean(rewards[-100:]))
        
        plt.title('QLearning with ER on CartPole-v0, buffer_size={}, batch_size={}'.format(buffer_size, bsize))
        plt.xlabel('game number')
        plt.ylabel('mean reward')
        plt.plot(rewards)
        plt.show()
# Out:
# mean reward 200.0

# %% [markdown]
# Видим, что ER в разы ускоряет обучение агента. В ходе экспериментов было замечено, что слишком большой размер буфера может мешать обучению. Видимо, это связано с тем, что большой буфер хранит больше плохих примеров.

# %% [markdown]
# ### Bonus I: TD($ \lambda $) (5+ points)
#
# There's a number of advanced algorithms you can find in week 3 materials (Silver lecture II and/or reading about eligibility traces). One such algorithm is TD(lambda), which is based on the idea of eligibility traces. You can also view it as a combination of N-step updates for alll N.
# * N-step temporal difference from Sutton's book - [url](http://incompleteideas.net/sutton/book/ebook/node73.html)
# * Eligibility traces from Sutton's book - [url](http://incompleteideas.net/sutton/book/ebook/node72.html)
# * Blog post on eligibility traces - [url](http://pierrelucbacon.com/traces/)
#
#
#
# Implementing this algorithm will prove more challenging than q-learning or sarsa, but doing so will earn you a deeper understanding of how value-based methods work [in addition to some bonus points].
#
# More kudos for comparing and analyzing TD($\lambda$) against Q-learning and EV-SARSA in different setups (taxi vs cartpole, constant epsilon vs decreasing epsilon).

# %% [markdown]
# ### Bonus II: More pacman (5+ points)
#
# Remember seminar_main where your vanilla q-learning had hard time solving Pacman even on a small grid. Now's the time to fix that issue.
#
# We'll focus on those grids for pacman setup.
# * python pacman.py -p PacmanQAgent -x N_TRAIN_GAMES -n N_TOTAL_GAMES -l __mediumGrid__
# * python pacman.py -p PacmanQAgent -x N_TRAIN_GAMES -n N_TOTAL_GAMES -l __mediumClassic__
#
# Even if you adjust N_TRAIN_GAMES to 10^5 and N_TOTAL_GAMES to 10^5+100 (100 last games are for test), pacman won't solve those environments
#
# The problem with those environments is that they have a large amount of unique states. However, you can devise a smaller environment state by choosing different observation parameters, e.g.:
#  * distance and direction to nearest ghost
#  * where is nearest food
#  * 'center of mass' of all food points (and variance, and whatever)
#  * is there a wall in each direction
#  * and anything else you see fit
#
# Here's how to get this information from [state](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/pacman.py#L49),
#  * Get pacman position: [state.getPacmanPosition()](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/pacman.py#L128)
#  * Is there a wall at (x,y)?: [state.hasWall(x,y)](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/pacman.py#L189)
#  * Get ghost positions: [state.getGhostPositions()](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/pacman.py#L144)
#  * Get all food positions: [state.getCapsules()](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/pacman.py#L153)
#
# You can call those methods anywhere you see state.
#  * e.g. in [agent.getValue(state)](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/qlearningAgents.py#L52)
#  * Defining a function that extracts all features and calling it in [getQValue](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/qlearningAgents.py#L38) and [setQValue](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/qlearningAgents.py#L44) is probably enough.
#  * You can also change agent parameters. The simplest way is to hard-code them in [PacmanQAgent](https://github.com/yandexdataschool/Practical_RL/blob/master/week2/assignment/qlearningAgents.py#L140)
#
# Also, don't forget to optimize ```learning_rate```, ```discount``` and ```epsilon``` params of model, this may also help to solve this env.
